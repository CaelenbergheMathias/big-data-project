# %%
import pandas as pd
import numpy as np
set1 = pd.read_csv('flights_2010_000000000000.gzip',compression='gzip',parse_dates=True,index_col='date')
print(set1.info())
set2 = pd.read_csv('flights_2010_000000000001.gzip',compression='gzip',parse_dates=True,index_col='date')
print(set2.info())
set3 = pd.read_csv('flights_2010_000000000002.gzip',compression='gzip',parse_dates=True,index_col='date')
print(set3.info())
set4 = pd.read_csv('flights_2010_000000000003.gzip',compression='gzip',parse_dates=True,index_col='date')
print(set4.info())
set5 = pd.read_csv('flights_2010_000000000004.gzip',compression='gzip',parse_dates=True,index_col='date')
print(set5.info())
set6 = pd.read_csv('flights_2010_000000000005.gzip',compression='gzip',parse_dates=True,index_col='date')
print(set6.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1898651 entries, 2012-11-25 to 2012-04-03
# Data columns (total 16 columns):
# airline               object
# airline_code          int64
# departure_airport     object
# departure_state       object
# departure_lat         float64
# departure_lon         float64
# arrival_airport       object
# arrival_state         object
# arrival_lat           float64
# arrival_lon           float64
# departure_schedule    int64
# departure_actual      int64
# departure_delay       int64
# arrival_schedule      int64
# arrival_actual        int64
# arrival_delay         int64
# dtypes: float64(4), int64(7), object(5)
# memory usage: 246.3+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1900889 entries, 2012-11-25 to 2012-04-01
# Data columns (total 16 columns):
# airline               object
# airline_code          int64
# departure_airport     object
# departure_state       object
# departure_lat         float64
# departure_lon         float64
# arrival_airport       object
# arrival_state         object
# arrival_lat           float64
# arrival_lon           float64
# departure_schedule    float64
# departure_actual      int64
# departure_delay       int64
# arrival_schedule      float64
# arrival_actual        int64
# arrival_delay         int64
# dtypes: float64(6), int64(5), object(5)
# memory usage: 246.5+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1901278 entries, 2012-11-25 to 2012-04-07
# Data columns (total 16 columns):
# airline               object
# airline_code          int64
# departure_airport     object
# departure_state       object
# departure_lat         float64
# departure_lon         float64
# arrival_airport       object
# arrival_state         object
# arrival_lat           float64
# arrival_lon           float64
# departure_schedule    int64
# departure_actual      int64
# departure_delay       int64
# arrival_schedule      float64
# arrival_actual        int64
# arrival_delay         int64
# dtypes: float64(5), int64(6), object(5)
# memory usage: 246.6+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1899791 entries, 2012-11-23 to 2012-04-06
# Data columns (total 16 columns):
# airline               object
# airline_code          int64
# departure_airport     object
# departure_state       object
# departure_lat         float64
# departure_lon         float64
# arrival_airport       object
# arrival_state         object
# arrival_lat           float64
# arrival_lon           float64
# departure_schedule    int64
# departure_actual      int64
# departure_delay       int64
# arrival_schedule      int64
# arrival_actual        int64
# arrival_delay         int64
# dtypes: float64(4), int64(7), object(5)
# memory usage: 246.4+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1900479 entries, 2012-11-23 to 2012-04-08
# Data columns (total 16 columns):
# airline               object
# airline_code          int64
# departure_airport     object
# departure_state       object
# departure_lat         float64
# departure_lon         float64
# arrival_airport       object
# arrival_state         object
# arrival_lat           float64
# arrival_lon           float64
# departure_schedule    int64
# departure_actual      int64
# departure_delay       int64
# arrival_schedule      int64
# arrival_actual        int64
# arrival_delay         int64
# dtypes: float64(4), int64(7), object(5)
# memory usage: 246.5+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1900108 entries, 2012-11-25 to 2012-04-10
# Data columns (total 16 columns):
# airline               object
# airline_code          int64
# departure_airport     object
# departure_state       object
# departure_lat         float64
# departure_lon         float64
# arrival_airport       object
# arrival_state         object
# arrival_lat           float64
# arrival_lon           float64
# departure_schedule    int64
# departure_actual      int64
# departure_delay       int64
# arrival_schedule      int64
# arrival_actual        int64
# arrival_delay         int64
# dtypes: float64(4), int64(7), object(5)
# memory usage: 246.4+ MB
# None

# %%
print(set6.values[0])
# Out:
# ['US' 20355 'CLT' 'NC' 35.21 -80.94 'PHL' 'PA' 39.87 -75.24 630 625 -5 808
#  815 7]
