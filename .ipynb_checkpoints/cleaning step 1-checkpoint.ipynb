# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
set1 = pd.read_csv('flights_2010_000000000000.gzip',compression='gzip',index_col='date')

set2 = pd.read_csv('flights_2010_000000000001.gzip',compression='gzip',index_col='date')

set3 = pd.read_csv('flights_2010_000000000002.gzip',compression='gzip',index_col='date')

set4 = pd.read_csv('flights_2010_000000000003.gzip',compression='gzip',index_col='date')

set5 = pd.read_csv('flights_2010_000000000004.gzip',compression='gzip',index_col='date')

set6 = pd.read_csv('flights_2010_000000000005.gzip',compression='gzip',index_col='date')

# %%
combo = pd.concat([set1,set2,set3,set4,set5,set6])

# %%
combo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11401196 entries, 2012-11-25 to 2012-04-10
# Data columns (total 16 columns):
# airline               object
# airline_code          int64
# departure_airport     object
# departure_state       object
# departure_lat         float64
# departure_lon         float64
# arrival_airport       object
# arrival_state         object
# arrival_lat           float64
# arrival_lon           float64
# departure_schedule    float64
# departure_actual      int64
# departure_delay       int64
# arrival_schedule      float64
# arrival_actual        int64
# arrival_delay         int64
# dtypes: float64(6), int64(5), object(5)
# memory usage: 1.4+ GB

# %%
combo = combo.drop_duplicates()

# %%
combo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10751921 entries, 2012-11-25 to 2012-04-10
# Data columns (total 16 columns):
# airline               object
# airline_code          int64
# departure_airport     object
# departure_state       object
# departure_lat         float64
# departure_lon         float64
# arrival_airport       object
# arrival_state         object
# arrival_lat           float64
# arrival_lon           float64
# departure_schedule    float64
# departure_actual      int64
# departure_delay       int64
# arrival_schedule      float64
# arrival_actual        int64
# arrival_delay         int64
# dtypes: float64(6), int64(5), object(5)
# memory usage: 1.4+ GB

# %%
combo.to_csv('cleaningStep1.gzip',compression='gzip')

# %%
combo.head()
# Out:
#            airline  airline_code departure_airport departure_state  \
# date
# 2012-11-25      US         20355               CLT              NC
# 2012-11-29      US         20355               CLT              NC
# 2012-11-29      US         20355               CLT              NC
# 2012-11-29      US         20355               CLT              NC
# 2012-11-29      US         20355               CLT              NC
#
#             departure_lat  departure_lon arrival_airport arrival_state  \
# date
# 2012-11-25          35.21         -80.94             PHL            PA
# 2012-11-29          35.21         -80.94             PHL            PA
# 2012-11-29          35.21         -80.94             PHL            PA
# 2012-11-29          35.21         -80.94             PHL            PA
# 2012-11-29          35.21         -80.94             PHL            PA
#
#             arrival_lat  arrival_lon  departure_schedule  departure_actual  \
# date
# ...
